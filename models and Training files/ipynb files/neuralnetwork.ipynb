# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load and preprocess the data
df1 = pd.read_csv('2014-15.csv')
df2 = pd.read_csv('2015-16.csv')
df3 = pd.read_csv('2016-17.csv')
df4 = pd.read_csv('2017-18.csv')
df5 = pd.read_csv('2018-19.csv')
df6 = pd.read_csv('2019-20.csv')
df7 = pd.read_csv('2021.csv')
df8 = pd.read_csv('2022.csv')
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8])
df.sort_values(by=['HomeTeam'], ascending=True, inplace=True)
df.dropna(subset=['FTHG', 'FTAG', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR'], inplace=True)
scaler = StandardScaler()
normalized_data = scaler.fit_transform(df[['FTHG','FTAG','HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']])
weights = [0.25, 0.15, 0.2, 0.1, 0.1, 0.1, 0.1]
home_team_rating = normalized_data[:, [0, 2, 4, 6, 8, 10, 12]].dot(weights)
away_team_rating = normalized_data[:, [1, 3, 5, 7, 9, 11, 13]].dot(weights)
X = pd.DataFrame({'HomeTeamRating': home_team_rating, 'AwayTeamRating': away_team_rating})
y = df['FTR'].apply(lambda x: 1 if x == 'H' else 0)

# Split the data into training, validation, and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1000)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1000)

# Create the neural network model
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val))

# Make predictions and evaluate the model performance on validation set
y_pred_val = np.round(model.predict(X_val))
accuracy_val = accuracy_score(y_val, y_pred_val)
precision_val, recall_val, f1_score_val,_= precision_recall_fscore_support(y_val, y_pred_val, average='binary')

print("Validation set performance:")
print("Accuracy:", accuracy_val)
print("Precision:", precision_val)
print("Recall:", recall_val)
print("F1-score:", f1_score_val)

# Make predictions and evaluate the model performance on testing set

y_pred_test = np.round(model.predict(X_test))
accuracy_test = accuracy_score(y_test, y_pred_test)
precision_test, recall_test, f1_score_test, _ = precision_recall_fscore_support(y_test, y_pred_test, average='binary')

print("Testing set performance:")
print("Accuracy:", accuracy_test)
print("Precision:", precision_test)
print("Recall:", recall_test)
# Out:
# Epoch 1/50
# 51/51 [==============================] - 2s 10ms/step - loss: 0.6670 - accuracy: 0.6784 - val_loss: 0.6395 - val_accuracy: 0.7407
# Epoch 2/50
# 51/51 [==============================] - 0s 5ms/step - loss: 0.6111 - accuracy: 0.7611 - val_loss: 0.5826 - val_accuracy: 0.7481
# Epoch 3/50
# 51/51 [==============================] - 0s 5ms/step - loss: 0.5564 - accuracy: 0.7728 - val_loss: 0.5324 - val_accuracy: 0.7574
# Epoch 4/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.5158 - accuracy: 0.7667 - val_loss: 0.5030 - val_accuracy: 0.7593
# Epoch 5/50
# 51/51 [==============================] - 0s 5ms/step - loss: 0.4952 - accuracy: 0.7691 - val_loss: 0.4921 - val_accuracy: 0.7593
# Epoch 6/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4865 - accuracy: 0.7685 - val_loss: 0.4875 - val_accuracy: 0.7648
# Epoch 7/50
# 51/51 [==============================] - 0s 5ms/step - loss: 0.4832 - accuracy: 0.7679 - val_loss: 0.4858 - val_accuracy: 0.7685
# Epoch 8/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4818 - accuracy: 0.7728 - val_loss: 0.4845 - val_accuracy: 0.7648
# Epoch 9/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4805 - accuracy: 0.7698 - val_loss: 0.4829 - val_accuracy: 0.7648
# Epoch 10/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4804 - accuracy: 0.7679 - val_loss: 0.4828 - val_accuracy: 0.7667
# Epoch 11/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4797 - accuracy: 0.7704 - val_loss: 0.4829 - val_accuracy: 0.7648
# Epoch 12/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4793 - accuracy: 0.7716 - val_loss: 0.4805 - val_accuracy: 0.7611
# Epoch 13/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4793 - accuracy: 0.7704 - val_loss: 0.4839 - val_accuracy: 0.7667
# Epoch 14/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4785 - accuracy: 0.7722 - val_loss: 0.4809 - val_accuracy: 0.7630
# Epoch 15/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4786 - accuracy: 0.7759 - val_loss: 0.4806 - val_accuracy: 0.7611
# Epoch 16/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4782 - accuracy: 0.7722 - val_loss: 0.4822 - val_accuracy: 0.7667
# Epoch 17/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4779 - accuracy: 0.7728 - val_loss: 0.4802 - val_accuracy: 0.7593
# Epoch 18/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4781 - accuracy: 0.7747 - val_loss: 0.4809 - val_accuracy: 0.7630
# Epoch 19/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4777 - accuracy: 0.7716 - val_loss: 0.4809 - val_accuracy: 0.7611
# Epoch 20/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4772 - accuracy: 0.7735 - val_loss: 0.4795 - val_accuracy: 0.7593
# Epoch 21/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4788 - accuracy: 0.7679 - val_loss: 0.4781 - val_accuracy: 0.7556
# Epoch 22/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4776 - accuracy: 0.7728 - val_loss: 0.4837 - val_accuracy: 0.7704
# Epoch 23/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4778 - accuracy: 0.7698 - val_loss: 0.4803 - val_accuracy: 0.7611
# Epoch 24/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4779 - accuracy: 0.7735 - val_loss: 0.4782 - val_accuracy: 0.7593
# Epoch 25/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4770 - accuracy: 0.7735 - val_loss: 0.4815 - val_accuracy: 0.7667
# Epoch 26/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4771 - accuracy: 0.7747 - val_loss: 0.4835 - val_accuracy: 0.7685
# Epoch 27/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4771 - accuracy: 0.7753 - val_loss: 0.4819 - val_accuracy: 0.7685
# Epoch 28/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4763 - accuracy: 0.7735 - val_loss: 0.4798 - val_accuracy: 0.7611
# Epoch 29/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4769 - accuracy: 0.7765 - val_loss: 0.4831 - val_accuracy: 0.7667
# Epoch 30/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4765 - accuracy: 0.7735 - val_loss: 0.4804 - val_accuracy: 0.7667
# Epoch 31/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4763 - accuracy: 0.7691 - val_loss: 0.4793 - val_accuracy: 0.7611
# Epoch 32/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4766 - accuracy: 0.7716 - val_loss: 0.4798 - val_accuracy: 0.7611
# Epoch 33/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4760 - accuracy: 0.7722 - val_loss: 0.4804 - val_accuracy: 0.7611
# Epoch 34/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4763 - accuracy: 0.7704 - val_loss: 0.4787 - val_accuracy: 0.7611
# Epoch 35/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4767 - accuracy: 0.7704 - val_loss: 0.4798 - val_accuracy: 0.7611
# Epoch 36/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4760 - accuracy: 0.7747 - val_loss: 0.4802 - val_accuracy: 0.7630
# Epoch 37/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4756 - accuracy: 0.7722 - val_loss: 0.4818 - val_accuracy: 0.7667
# Epoch 38/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4756 - accuracy: 0.7759 - val_loss: 0.4797 - val_accuracy: 0.7630
# Epoch 39/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4756 - accuracy: 0.7753 - val_loss: 0.4809 - val_accuracy: 0.7630
# Epoch 40/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4758 - accuracy: 0.7741 - val_loss: 0.4817 - val_accuracy: 0.7667
# Epoch 41/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4760 - accuracy: 0.7679 - val_loss: 0.4776 - val_accuracy: 0.7556
# Epoch 42/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4752 - accuracy: 0.7741 - val_loss: 0.4808 - val_accuracy: 0.7648
# Epoch 43/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4755 - accuracy: 0.7759 - val_loss: 0.4828 - val_accuracy: 0.7685
# Epoch 44/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4755 - accuracy: 0.7728 - val_loss: 0.4800 - val_accuracy: 0.7648
# Epoch 45/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4754 - accuracy: 0.7753 - val_loss: 0.4786 - val_accuracy: 0.7611
# Epoch 46/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4759 - accuracy: 0.7735 - val_loss: 0.4786 - val_accuracy: 0.7611
# Epoch 47/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4753 - accuracy: 0.7728 - val_loss: 0.4794 - val_accuracy: 0.7630
# Epoch 48/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4749 - accuracy: 0.7753 - val_loss: 0.4802 - val_accuracy: 0.7630
# Epoch 49/50
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4753 - accuracy: 0.7716 - val_loss: 0.4819 - val_accuracy: 0.7667
# Epoch 50/50
# 51/51 [==============================] - 0s 4ms/step - loss: 0.4750 - accuracy: 0.7728 - val_loss: 0.4807 - val_accuracy: 0.7648
# 17/17 [==============================] - 0s 1ms/step
# Validation set performance:
# Accuracy: 0.7648148148148148
# Precision: 0.7715736040609137
# Recall: 0.6495726495726496
# F1-score: 0.7053364269141532
# 17/17 [==============================] - 0s 1ms/step
# Testing set performance:
# Accuracy: 0.7277777777777777
# Precision: 0.735
# Recall: 0.6099585062240664
